# %% [markdown]
# # The following lines show the code for the first part of the task. Please scroll down further for the second part.

# %% [markdown]
# Import the necessary libraries such as Pandas

# %%
import pandas as pd

# %% [markdown]
# Retrieve the data from the URL and create a dataframe with the information we only need.

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
df = pd.read_html(url)
df = df[0]

# %% [markdown]
# Remove every row where the value in the column "Borough" is "Not assigned"

# %%
df = df[df["Borough"] != "Not assigned"]
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# The frame already has multiple neighbourhoods in the same row if their postal code is identical

# %%
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# The following code shows there are no rows in this frame which have a neighbourhood with the value "Not assigned"

# %%
df_notAssignedHoods = df[df["Neighbourhood"] == "Not assigned"]
df_notAssignedHoods.shape[0]
# Out:
# 0

# %% [markdown]
# Reset the index so the numbers match to the current length of the dataframe

# %%
df2 = df.reset_index()
df2 = df2.drop(["index"], axis = 1)
df2.tail()
# Out:
#     Postal Code           Borough  \
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...

# %% [markdown]
# Show the dimensions of the dataframe

# %%
df2.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part 2 of the assignment starts here

# %% [markdown]
# Install the geocoder package and import it

# %%
# !pip install geocoder
# Out:
# ...
#      |████████████████████████████████| 98 kB 8.6 MB/s  eta 0:00:01
# ...

# %%
import geocoder
print("Imported!")
# Out:
# Imported!

# %% [markdown]
# Import the data from the url into a different dataframe, since using the package itself to retrieve the data proved to be inconsistent

# %%
url_geo = "https://cocl.us/Geospatial_data"
dfg = pd.read_csv(url_geo)

# %%
dfg.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Merge the dataframes with the neighbourhoods, postal codes etc. with the other frame containing the geographical spots

# %%
df3 = df2
df3 = df3.merge(dfg)

# %% [markdown]
# Sort the rows by the postal code and reset the index to make sure the numbers are displayed consistently

# %%
df3 = df3.sort_values(by = ["Postal Code"])
df3 = df3.reset_index()
df3 = df3.drop("index", axis = 1)

# %% [markdown]
# The following line should display the dataframe to look as it´s supposed to be

# %%
df3.head(11)
# Out:
#    Postal Code      Borough  \
# 0          M1B  Scarborough
# 1          M1C  Scarborough
# 2          M1E  Scarborough
# 3          M1G  Scarborough
# 4          M1H  Scarborough
# 5          M1J  Scarborough
# 6          M1K  Scarborough
# 7          M1L  Scarborough
# 8          M1M  Scarborough
# 9          M1N  Scarborough
# 10         M1P  Scarborough
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                      Malvern, Rouge  43.806686 -79.194353
# 1              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                              Woburn  43.770992 -79.216917
# 4                                           Cedarbrae  43.773136 -79.239476
# 5                                 Scarborough Village  43.744734 -79.239476
# 6         Kennedy Park, Ionview, East Birchmount Park  43.727929 -79.262029
# ...

# %%
df3.shape
# Out:
# (103, 5)
